# %% [markdown]
# # Preparando Imagens para treinamento

# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import numpy as np
import torch
import torchvision.transforms as transforms
from PIL import Image
import cv2
import os

# %% [markdown]
# # Lendo as Imagens

# %%
df_read = pd.read_json("datasets/dataset_pernambuco_25_turistas.json")

all_imgs = df_read[["id", "imagem", "tags"]]
for imagem in all_imgs:
    print(f"🎯 Encontradas {imagem[imagem]}")
